# %% [markdown]
# # 1. проведем разведовательный анализ (EDA) данных
# для начала импортируем используемые библиотеки

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
# %matplotlib inline
import seaborn as sns 

import plotly
import plotly.express as px
import plotly.graph_objects as go
import cufflinks as cf
import plotly.offline as pyo
from plotly.offline import init_notebook_mode,plot,iplot

from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler
from pandas import Series
from sklearn.feature_selection import f_classif, mutual_info_classif

# %%
data = pd.read_csv('dataset_V2.csv')
data.head(3)
# Out:
#    Unnamed: 0           bodyType  brand  \
# 0           0            лифтбек  SKODA
# 1           1            лифтбек  SKODA
# 2           2  внедорожник 5 дв.  SKODA
#
#                                              car_url      color  \
# 0  https://auto.ru/cars/used/sale/skoda/octavia/1...      белый
# 1  https://auto.ru/cars/used/sale/skoda/octavia/1...    бежевый
# 2  https://auto.ru/cars/used/sale/skoda/yeti/1105...  пурпурный
#
#                                          description engineDisplacement  \
# 0  Машина в отличном состоянии🥇\nКомплектация Ele...            1.8 LTR
# 1  Хорошее техническое и косметическое\nсостояние...            1.8 LTR
# 2  Идеальное состояние автомобиля\nДилер Краснояр...            1.2 LTR
#
#   enginePower                                     equipment_dict fuelType  \
# 0     152 N12  {'cruise-control': True, 'tinted-glass': True,...   бензин
# 1     152 N12  {'cruise-control': True, 'esp': True, 'adaptiv...   бензин
# 2     105 N12  {'computer': True, 'ptf': True, 'rain-sensor':...   бензин
#
#    ...    vendor  Владельцы        ПТС           Привод  Руль  Состояние  \
# 0  ...  EUROPEAN        2.0  DUPLICATE  FORWARD_CONTROL  LEFT       True
# 1  ...  EUROPEAN        3.0   ORIGINAL  FORWARD_CONTROL  LEFT       True
# 2  ...  EUROPEAN        1.0   ORIGINAL  FORWARD_CONTROL  LEFT       True
#
#   Таможня     price      id_car rate_fuel
# 0    True  829000.0  1105765221       7.7
# 1    True  785000.0  1105672391       7.7
# 2    True  745000.0  1105201873       6.4
#
# [3 rows x 29 columns]

# %%
test = pd.read_csv('test.csv')
test.sample(3)
# Out:
#                 bodyType   brand  \
# 871      универсал 5 дв.   SKODA
# 7677               седан     BMW
# 11073  внедорожник 5 дв.  NISSAN
#
#                                                  car_url  color  \
# 871    https://auto.ru/cars/used/sale/skoda/fabia/109...  серый
# 7677   https://auto.ru/cars/used/sale/bmw/3er/1101273...  белый
# 11073  https://auto.ru/cars/used/sale/nissan/murano/1...  синий
#
#                                       complectation_dict  \
# 871                                                  NaN
# 7677   {"id":"21766317","name":"320d xDrive M Sport P...
# 11073                                                NaN
#
#                                              description engineDisplacement  \
# 871    Хорошая машина, маленький расход бензина. \nТо...            1.4 LTR
# 7677   «Inchcape Certified-  Первый международный офи...            2.0 LTR
# 11073  РОЛЬФ - Официальный дилер и Лучший дилер Росси...            3.5 LTR
#
#       enginePower                                     equipment_dict fuelType  \
# 871        86 N12  {"ptf":true,"airbag-driver":true,"electro-wind...   бензин
# 7677      190 N12  {"cruise-control":true,"asr":true,"esp":true,"...   дизель
# 11073     249 N12  {"cruise-control":true,"engine-proof":true,"as...   бензин
#
#        ...          vehicleConfiguration  vehicleTransmission    vendor  \
# 871    ...  WAGON_5_DOORS MECHANICAL 1.4         механическая  EUROPEAN
# 7677   ...           SEDAN AUTOMATIC 2.0       автоматическая  EUROPEAN
# 11073  ...  ALLROAD_5_DOORS VARIATOR 3.5             вариатор  JAPANESE
#
#         Владельцы            Владение       ПТС    Привод   Руль  \
# 871    1 владелец  10 лет и 9 месяцев  Оригинал  передний  Левый
# 7677   1 владелец                 NaN  Оригинал    полный  Левый
# 11073  1 владелец                 NaN  Оригинал  передний  Левый
#
#                 Состояние     Таможня
# 871    Не требует ремонта  Растаможен
# 7677   Не требует ремонта  Растаможен
# 11073  Не требует ремонта  Растаможен
#
# [3 rows x 32 columns]

# %%
sample = pd.read_csv('sample_submission.csv')
sample.sample(3)
# Out:
#           sell_id  price
# 4884   1099434854      0
# 12816  1100042140      0
# 16955  1101143395      0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94352 entries, 0 to 94351
# Data columns (total 29 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            94352 non-null  int64
#  1   bodyType              94352 non-null  object
#  2   brand                 94352 non-null  object
#  3   car_url               94352 non-null  object
#  4   color                 94352 non-null  object
#  5   description           94352 non-null  object
#  6   engineDisplacement    94352 non-null  object
#  7   enginePower           94352 non-null  object
#  8   equipment_dict        94352 non-null  object
#  9   fuelType              94352 non-null  object
#  10  mileage               94352 non-null  float64
#  11  modelDate             94352 non-null  float64
#  12  model_info            94352 non-null  object
#  13  model_name            94352 non-null  object
#  14  numberOfDoors         94352 non-null  float64
#  15  productionDate        94352 non-null  float64
#  16  super_gen             94352 non-null  object
#  17  vehicleConfiguration  94352 non-null  object
#  18  vehicleTransmission   94352 non-null  object
#  19  vendor                94352 non-null  object
#  20  Владельцы             94352 non-null  float64
#  21  ПТС                   94352 non-null  object
#  22  Привод                94352 non-null  object
#  23  Руль                  94352 non-null  object
#  24  Состояние             94352 non-null  bool
#  25  Таможня               94352 non-null  bool
#  26  price                 94352 non-null  float64
#  27  id_car                94352 non-null  int64
#  28  rate_fuel             94352 non-null  float64
# dtypes: bool(2), float64(7), int64(2), object(18)
# memory usage: 19.6+ MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34686 entries, 0 to 34685
# Data columns (total 32 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   bodyType              34686 non-null  object
#  1   brand                 34686 non-null  object
#  2   car_url               34686 non-null  object
#  3   color                 34686 non-null  object
#  4   complectation_dict    6418 non-null   object
#  5   description           34686 non-null  object
#  6   engineDisplacement    34686 non-null  object
#  7   enginePower           34686 non-null  object
#  8   equipment_dict        24690 non-null  object
#  9   fuelType              34686 non-null  object
#  10  image                 34686 non-null  object
#  11  mileage               34686 non-null  int64
#  12  modelDate             34686 non-null  int64
#  13  model_info            34686 non-null  object
#  14  model_name            34686 non-null  object
#  15  name                  34686 non-null  object
#  16  numberOfDoors         34686 non-null  int64
#  17  parsing_unixtime      34686 non-null  int64
#  18  priceCurrency         34686 non-null  object
#  19  productionDate        34686 non-null  int64
#  20  sell_id               34686 non-null  int64
#  21  super_gen             34686 non-null  object
#  22  vehicleConfiguration  34686 non-null  object
#  23  vehicleTransmission   34686 non-null  object
#  24  vendor                34686 non-null  object
#  25  Владельцы             34686 non-null  object
#  26  Владение              11995 non-null  object
#  27  ПТС                   34685 non-null  object
#  28  Привод                34686 non-null  object
#  29  Руль                  34686 non-null  object
#  30  Состояние             34686 non-null  object
#  31  Таможня               34686 non-null  object
# dtypes: int64(6), object(26)
# memory usage: 8.5+ MB

# %% [markdown]
# как видно из данных, в тестовом датасете нет целевой переменной, которую необходимо предсказать. добавим ее

# %%
test['price'] = 1
test.shape
# Out:
# (34686, 33)

# %% [markdown]
# добавим функции, которые будут отрисовывать распределение признаков

# %%
from matplotlib import rcParams
rcParams['figure.figsize'] = 10, 6

def categorial_feature(column, data, rotate=90, x_shift_mult=0, percentage=True, num_categories=10):
    values = data[column].value_counts().index
    if len(values) > num_categories:
        values = values[:num_categories]
    values = list(values)
    data_curr_categories = data.query(f"{column} in {values}")
    curr_categories = data_curr_categories[column].values

    ax = sns.countplot(x=curr_categories, data=data, 
                       order=data[column].value_counts().index[:num_categories], 
                       orient="h", palette ="Spectral")
    
    if percentage:
        total = len(data[column])
        for p in ax.patches:
            percentage = '{:.1f}%'.format(100 * p.get_height()/total) #добавим в подпись процентное соотношение
            x = p.get_x() + x_shift_mult*p.get_width()
            y = p.get_y() + p.get_height()+8
            ax.annotate(percentage, (x, y)) 
    plt.xticks(rotation=rotate)


def numeric_feature(data, bins=10):
    print(data.describe()[["min", "max", "25%", "50%", "75%", "std"]])
    sns.distplot(data, bins=bins)
    

def plot_cat_col_vs_price(data, col, num_categories=3):
    values = data[col].value_counts().index
    if len(values) > num_categories:
        values = values[:num_categories]
    values = list(values)
    data_curr_categories = data.query(f"{col} in {values}")
    curr_categories = data_curr_categories[col].values
    sns.boxplot(x=curr_categories, y=data_curr_categories['price'], data = data)
    plt.title(col)
    plt.grid()

# %% [markdown]
# добавим функции, которые будем использовать в работе

# %%
#функция, показывающая основные статистики параметра
def print_col_info(dataset):
    print(f"Количество пропущенных значений: {dataset.isna().sum()}")

# %% [markdown]
# проверим наличие дубликатов и пропусков в тестовом и тренировочном датасете

# %%
print (f'Дубликаты: {data.duplicated().sum()}')
print (display(data.isna().sum()[data.isna().sum() > 0]))
colours = ['blue', 'red']
plt.figure(figsize=(16, 6))
sns.heatmap(data.isnull(), cmap=sns.color_palette(colours))
# Out:
# Дубликаты: 0
# Series([], dtype: int64)
# None
# <AxesSubplot:>

# %%
print (f'Дубликаты: {test.duplicated().sum()}')
print (display(test.isna().sum()[test.isna().sum() > 0]))
colours = ['pink', 'green']
plt.figure(figsize=(16, 6))
sns.heatmap(test.isnull(), cmap=sns.color_palette(colours))
# Out:
# Дубликаты: 0
# complectation_dict    28268
# equipment_dict         9996
# Владение              22691
# ПТС                       1
# dtype: int64
# None
# <AxesSubplot:>

# %% [markdown]
# как видно - дубликтов в обоих датасетах нет, но в тестовом есть признаки с пропусками, при том в некоторых показателях их существенное количество. К ним относятся: complectation_dict, equipment_dict, Владение, ПТС. В дальнейшем их рассмотрим подробнее и примем решение об их использовании. Признак цены был добавлен и там еще нет данных.

# %% [markdown]
# Разделим признаки по видам.
# - Категориальные: 'bodyType', 'brand', 'color', 'fuelType', 'model_name', 'vehicleTransmission', 'vendor', 'Владельцы', 'Владение', 'ПТС', 'Привод', 'Руль', 'Состояние', 'Таможня'
# - Числовые: 'mileage', 'numberOfDoors', 'sell_id', 'price'
# - Временные: 'modelDate', 'productionDate', 'parsing_unixtime'
# - Описательные: 'complectation_dict', 'description', 'engineDisplacement', 'enginePower', 'equipment_dict', 'model_info', 'name', 'vehicleConfiguration'

# %% [markdown]
# # Категориальные признаки

# %%
cat_features = ['bodyType', 'brand', 'color', 'fuelType', 'model_name', 'vehicleTransmission', 'vendor', 
                'Владельцы', 'ПТС', 'Привод', 'Руль', 'Состояние', 'Таможня']

dict_category = {}
for category in cat_features:
    data_category = test[category].value_counts()
    dict_category[category] = len(data_category)

print (dict_category)
# Out:
# {'bodyType': 24, 'brand': 12, 'color': 16, 'fuelType': 5, 'model_name': 544, 'vehicleTransmission': 4, 'vendor': 2, 'Владельцы': 3, 'ПТС': 2, 'Привод': 3, 'Руль': 2, 'Состояние': 1, 'Таможня': 1}

# %%
dict_category = {}
for category in cat_features:
    data_category = data[category].value_counts()
    dict_category[category] = len(data_category)

print (dict_category)
# Out:
# {'bodyType': 23, 'brand': 12, 'color': 16, 'fuelType': 5, 'model_name': 633, 'vehicleTransmission': 4, 'vendor': 3, 'Владельцы': 4, 'ПТС': 2, 'Привод': 3, 'Руль': 2, 'Состояние': 1, 'Таможня': 1}

# %% [markdown]
# как видно, в основном в признаки имеют относительно небольшое количество вариаций. Но следует отметить, что вариантов моделей автомобилей - 544 в тестовом датасете и 633 собранном, что существенно выбивается из общей тенденции. С другой стороны в таких признаках, как таможня и состояние всего по одному варианту, vendor (производитель) - 2 и 3 варианта соответственно, ПТС и Руль - по два. Для дальнейшего EDA-анализа можем их заменить на бинарные
# Ранее было обнаружено, что признаке ПТС в тестовых данных есть пропуск. Рассмотрим его ближе

# %%
test['ПТС'].value_counts()
# Out:
# Оригинал    30098
# Дубликат     4587
# Name: ПТС, dtype: int64

# %%
# заменим пропуск в этом признаке на наиболее часто встречающееся значение
test['ПТС'].fillna(test.ПТС.mode()[0], inplace=True)

# %% [markdown]
# ### bodyType

# %%
col = 'bodyType'
print_col_info(test[col])
print_col_info(data[col])
# Out:
# Количество пропущенных значений: 0
# Количество пропущенных значений: 0

# %%
categorial_feature(col, test, rotate=90)

# %%
categorial_feature(col, data, rotate=90)

# %%
col = 'bodyType'
plot_cat_col_vs_price(data, col)

# %% [markdown]
# как видно, наиболее распространенные модели кузова - это седан и 5дверный внедорожник, средняя цена которого выше других типов кузова

# %% [markdown]
# ### brand

# %%
col = 'brand'
print_col_info(test[col])
print_col_info(data[col])
# Out:
# Количество пропущенных значений: 0
# Количество пропущенных значений: 0

# %%
categorial_feature(col, test, rotate=45)

# %%
categorial_feature(col, data, rotate=45)

# %%
col = 'brand'
plot_cat_col_vs_price(data, col)

# %% [markdown]
# лидерами по моделям в тестовом датасете являются БМВ, Фольксвагены и Ниссаны,а также Мерседесы и Тойоты. Люксовых марок авто представлено меньше всего
# в тренировочном датасете на первом месте находятся Тойоты, Ниссан и Фольксвагены также раздеяют между собой 2е и 3е места. И здесь также видно, что бренд напрямую влияет на цену, и у самой распространенной марки средняя цена выше, а также наблюдается больших разброс цены.

# %% [markdown]
# ### model

# %%
col = 'model_name'
print_col_info(test[col])
print_col_info(data[col])
# Out:
# Количество пропущенных значений: 0
# Количество пропущенных значений: 0

# %%
column = 'model_name'
categorial_feature(column, test, rotate=45)

# %%
categorial_feature(column, data, rotate=45)

# %%
col = 'model_name'
plot_cat_col_vs_price(data, col)

# %% [markdown]
# в тестовом датасете наиболее популярные модели - это Шкода Октавиа, БМВ 5серии и Лансер от Митсубиси, в тренировочном - Шкода и БМВ также остались на первых местах, но Фольскваген Поло занял позицию Лансера. Также можно наблюдать, что у наиболее популярой модели оказалась более низка средняя цена по сравнению с БМВ, где и цена повыше, и разброс стоимости более широкий. У Поло средняя цена выше,но биапазон цен - меньше. И также следует отметить прямое влияние модели автомобиля на его цену

# %% [markdown]
# ### color

# %%
col = 'color'
print_col_info(test[col])
print_col_info(data[col])
# Out:
# Количество пропущенных значений: 0
# Количество пропущенных значений: 0

# %%
categorial_feature("color", test, rotate=45)

# %%
categorial_feature("color", data, rotate=45)

# %%
col = 'color'
plot_cat_col_vs_price(data, col)

# %% [markdown]
# самый распространенный цвет авто - черный. На boxplot видно, цвет машины не оказывает существенного воздействия на цену автомобиля

# %% [markdown]
# ### fuel

# %%
col = 'fuelType'
print_col_info(test[col])
print_col_info(data[col])
# Out:
# Количество пропущенных значений: 0
# Количество пропущенных значений: 0

# %%
categorial_feature("fuelType", test, rotate=0)

# %%
categorial_feature("fuelType", data, rotate=0)

# %%
col = 'fuelType'
plot_cat_col_vs_price(data, col)

# %% [markdown]
# бензиновые двигатели ожидаемо наиболее распространенные среди автомобилей, но при этом средняя цена выше у авто с дизельным двигателем

# %% [markdown]
# ### transmission

# %%
col = 'vehicleTransmission'
print_col_info(test[col])
print_col_info(data[col])
# Out:
# Количество пропущенных значений: 0
# Количество пропущенных значений: 0

# %%
categorial_feature("vehicleTransmission", test, rotate=0)

# %%
categorial_feature("vehicleTransmission", data, rotate=0)

# %%
col = 'vehicleTransmission'
plot_cat_col_vs_price(data, col)

# %% [markdown]
# наиболее часто встречающиеся авто - с АКПП, что обусловлено популярностью иномарок, и средняя цена таких  авто выше, на boxplot видна зависимость цены от типа КПП

# %% [markdown]
# ### vendor

# %%
col = 'vendor'
print_col_info(test[col])
print_col_info(data[col])
# Out:
# Количество пропущенных значений: 0
# Количество пропущенных значений: 0

# %%
categorial_feature("vendor", test, rotate=0)

# %%
categorial_feature("vendor", data, rotate=0)

# %%
# американских авто оказалось очень маленький % (меньше 0), рассмотрим этот признак ближе
data.vendor.value_counts()
# Out:
# EUROPEAN    50073
# JAPANESE    44273
# AMERICAN        6
# Name: vendor, dtype: int64

# %%
data.loc[data.vendor == 'AMERICAN']
# Out:
#        Unnamed: 0           bodyType       brand  \
# 81295       89685  внедорожник 5 дв.  VOLKSWAGEN
# 84557       93614            минивэн  VOLKSWAGEN
# 84914       94030            минивэн  VOLKSWAGEN
# 84915       94031            минивэн  VOLKSWAGEN
# 85429       94631            минивэн  VOLKSWAGEN
# 87001       96359  внедорожник 5 дв.  VOLKSWAGEN
#
#                                                  car_url    color  \
# 81295  https://auto.ru/cars/used/sale/volkswagen/atla...  красный
# 84557  https://auto.ru/cars/used/sale/volkswagen/euro...  красный
# 84914  https://auto.ru/cars/used/sale/volkswagen/euro...  зелёный
# 84915  https://auto.ru/cars/used/sale/volkswagen/euro...    синий
# 85429  https://auto.ru/cars/used/sale/volkswagen/euro...   чёрный
# 87001  https://auto.ru/cars/used/sale/volkswagen/atla...   чёрный
#
#                                              description engineDisplacement  \
# 81295  Хороший, качественный семейный автомобиль. Ест...            2.0 LTR
# 84557  Авто с реальным пробегом! Завезён в 2008 г. из...            2.8 LTR
# 84914  Продаю свой автомобиль. \nКузов в родной краск...            2.8 LTR
# 84915  Все вопросы по телефону. В салон не поставлю. ...            2.8 LTR
# 85429  Отличный семейный автомобиль. Езжу каждый день...            2.8 LTR
# 87001  Отличное авто!Состояние нового!Модификация 202...            2.0 LTR
#
#       enginePower                                     equipment_dict fuelType  \
# 81295     238 N12                                                 {}   бензин
# 84557     201 N12                                                 {}   бензин
# 84914     201 N12  {'cruise-control': True, 'engine-proof': True,...   бензин
# 84915     201 N12  {'cruise-control': True, 'engine-proof': True,...   бензин
# 85429     140 N12                                                 {}   бензин
# 87001     235 N12                                                 {}   бензин
#
#        ...    vendor  Владельцы       ПТС           Привод  Руль  Состояние  \
# 81295  ...  AMERICAN        1.0  ORIGINAL  FORWARD_CONTROL  LEFT       True
# 84557  ...  AMERICAN        1.0  ORIGINAL  FORWARD_CONTROL  LEFT       True
# 84914  ...  AMERICAN        3.0  ORIGINAL  FORWARD_CONTROL  LEFT       True
# 84915  ...  AMERICAN        3.0  ORIGINAL  FORWARD_CONTROL  LEFT       True
# 85429  ...  AMERICAN        3.0  ORIGINAL  FORWARD_CONTROL  LEFT       True
# 87001  ...  AMERICAN        1.0  ORIGINAL  ALL_WHEEL_DRIVE  LEFT       True
#
#       Таможня      price      id_car rate_fuel
# 81295    True  2950000.0  1105669057       9.8
# 84557    True   590000.0  1103781639       7.8
# 84914    True   730000.0  1105556887       7.8
# 84915    True   770000.0  1105220954       7.8
# 85429    True   650000.0  1105537751       7.8
# 87001    True  2900000.0  1104924511      10.7
#
# [6 rows x 29 columns]

# %%
# видимо, при заполнении анкеты произошла ошибка. Исправим данные
data['vendor'] = data['vendor'].str.replace(('AMERICAN'), 'EUROPEAN')

# %%
col = 'vendor'
plot_cat_col_vs_price(data, col)

# %% [markdown]
# вариантов производителей немного - либо европейские, либо японские, их распределение в тренировочном датасете приблизительно одинаковое. Также можно отметить, что распределение цены и средняя цена среди производителей авто приблизительно одинаковая

# %% [markdown]
# ### Владельцы

# %%
categorial_feature("Владельцы", test, rotate=0)

# %% [markdown]
# почти половина авто имеет более 3 владельцев. Т.к этот признак оказывает существенное влияние на цену, преобразуем его, сделаем числовым

# %%
owners_dict = {'1\xa0владелец': 1,
               '2\xa0владельца': 2,
               '3 или более': 3
               }
test.Владельцы = test.Владельцы.map(owners_dict)

# %% [markdown]
# # Числовые признаки

# %%
num_features = ['mileage', 'numberOfDoors']

# %%
# рассмотрим распределение числовых признаков
test[num_features].hist(figsize=(15, 8), bins=100)
# Out:
# array([[<AxesSubplot:title={'center':'mileage'}>,
#         <AxesSubplot:title={'center':'numberOfDoors'}>]], dtype=object)

# %%
numeric_feature(test.mileage, bins=15)
# Out:
# min          1.000000
# max    1000000.000000
# 25%      91153.500000
# 50%     149779.500000
# 75%     215000.000000
# std     100676.559489
# Name: mileage, dtype: float64
# C:\Users\007\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
numeric_feature(test.numberOfDoors, bins=15)
# Out:
# min    0.00000
# max    5.00000
# 25%    4.00000
# 50%    5.00000
# 75%    5.00000
# std    0.70304
# Name: numberOfDoors, dtype: float64
# C:\Users\007\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %% [markdown]
# На основе этих графиков можно сделать вывод, что пробег состявляет у большинства машин и для некоторых машин в пределе до 200 тыс. км . По второму графику видно, что основные категории составляют 4-5 дверные машины, имеется небольшой процент 2-х и 3-х дверных машин.
# Графики для modelDate и productionDate в целом очень похожи. Представленные машины были произведены в период с 1980 по 2020 годы (также имеются и более ранние машины, но их очень мало). Основную массу составляют машины примерно, начиная с 2010 года.

# %% [markdown]
# # Временные признаки

# %%
date_features = ['modelDate', 'productionDate', 'parsing_unixtime']

# %%
numeric_feature(test.modelDate, bins=15)
# Out:
# min    1904.000000
# max    2020.000000
# 25%    2004.000000
# 50%    2008.000000
# 75%    2012.000000
# std       7.415894
# Name: modelDate, dtype: float64
# C:\Users\007\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
numeric_feature(test.productionDate, bins=15)
# Out:
# min    1904.000000
# max    2020.000000
# 25%    2006.000000
# 50%    2011.000000
# 75%    2014.000000
# std       7.047661
# Name: productionDate, dtype: float64
# C:\Users\007\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %% [markdown]
# Год начала выпуска модели и год начала выпуска марок авто имеет ассиметричное распределение с длинным левым концом. Производство самой старой марки началось в 1904 году, самой новой - в 2020

# %% [markdown]
# для дальнейшего использования информации о годах выпуска преобразуем ее в возраст модели и марки автомобилей и добавим в качестве признака в датасет

# %%
test['modelAge'] = 2021 - test.modelDate
test['autoAge'] = 2021 - test.productionDate

# %%
num_features.append('autoAge')
num_features.append('modelAge')

# %%
#добавим преобразованный признак владельцев в список
num_features.append('Владельцы')

# %% [markdown]
# # Описательные признаки

# %%
desc_features = ['complectation_dict', 'description', 'engineDisplacement', 'enginePower', 'equipment_dict', 
                 'model_info', 'name', 'vehicleConfiguration']

# %% [markdown]
# в признаке 'engineDisplacement' 55 значений не заполнены, т.к в целом это количество незначительно, заменим его наиболее часто встречающимся

# %%
test['engineDisplacement'] = test['engineDisplacement'].apply(lambda x: '2.0 LTR' if x == ' LTR' else x)

# %%
#данные об объеме двигателя и его мощности преобразуем в число, чтобы можно было в дальнейшем с ними рабтать
test.engineDisplacement = test.engineDisplacement.str.findall(r"\d.\d").str[0]
test.engineDisplacement = test.engineDisplacement.astype('float64')

# %%
# внесем преобразованные признаки в список числовых
num_features.append('engineDisplacement')

# %%
# то же сделаем и с мощностью дигателя
test.enginePower = test.enginePower.str.findall(r'^\S+').str[0]
test.enginePower = test.enginePower.apply(lambda x: int(x))

# %%
num_features.append('enginePower')

# %%
test[['engineDisplacement', 'enginePower', 'name']]
# в колонке 'name' дублируется информация о мощности и объеме, но там также содержатся и другие данные,
# которые могут быть использованы в дальнейшем
# Out:
#        engineDisplacement  enginePower                                name
# 0                     1.2          105                  1.2 AMT (105 л.с.)
# 1                     1.6          110                   1.6 MT (110 л.с.)
# 2                     1.8          152              DSG 1.8 AMT (152 л.с.)
# 3                     1.6          110                   1.6 AT (110 л.с.)
# 4                     1.8          152                   1.8 AT (152 л.с.)
# ...                   ...          ...                                 ...
# 34681                 1.6          136              316i 1.6 AT (136 л.с.)
# 34682                 2.0          190  520d xDrive 2.0d AT (190 л.с.) 4WD
# 34683                 2.5          170              523i 2.5 AT (170 л.с.)
# 34684                 2.0          184          20d 2.0d AT (184 л.с.) 4WD
# 34685                 3.0          235          30d 3.0d AT (235 л.с.) 4WD
#
# [34686 rows x 3 columns]

# %%
numeric_feature(test.enginePower, bins=15)
# Out:
# min     30.000000
# max    639.000000
# 25%    125.000000
# 50%    169.000000
# 75%    233.000000
# std     89.087035
# Name: enginePower, dtype: float64
# C:\Users\007\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %% [markdown]
# как видно, мощность автомобилей ассиметричное распределение с длинным правым концом. Наиболее распространенные машины имеют мощность порядка 170 л.с, самые мощные авто в датасете имеют можность 639 л.с. Эти данныеможно использовать для рассчета транспортного налога. Созадим новый признак, разделив мощность на категории

# %%
# налоговая ставка зависит от мощности двигателя. Например, свыше 100 л.с. до 150 л.с. составляет 35 руб
def rate(power):
    if power > 250:
        return 150
    elif power > 200:
        return 75
    elif power > 150:
        return 50
    elif power > 100:
        return 35
    else:
        return 25

def calc_tax(row):
    return rate(row["enginePower"])*row["enginePower"]

test["tax"] = test.apply(lambda row: calc_tax(row), axis=1)

# %%
# внесем новый признак в список числовых
num_features.append('tax')

# %%
test[['engineDisplacement', 'enginePower', 'tax']]
# Out:
#        engineDisplacement  enginePower    tax
# 0                     1.2          105   3675
# 1                     1.6          110   3850
# 2                     1.8          152   7600
# 3                     1.6          110   3850
# 4                     1.8          152   7600
# ...                   ...          ...    ...
# 34681                 1.6          136   4760
# 34682                 2.0          190   9500
# 34683                 2.5          170   8500
# 34684                 2.0          184   9200
# 34685                 3.0          235  17625
#
# [34686 rows x 3 columns]

# %%
categorial_feature("engineDisplacement", test, rotate=90)

# %% [markdown]
# бОльшая часть представленных автомобилей имеют объем двигателя 2,0 л, затем 1,6 и 3,0 соответственно

# %%
print (num_features)
# Out:
# ['mileage', 'numberOfDoors', 'enginePower', 'tax', 'engineDisplacement', 'modelAge', 'autoAge', 'Владельцы']

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34686 entries, 0 to 34685
# Data columns (total 36 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   bodyType              34686 non-null  object
#  1   brand                 34686 non-null  object
#  2   car_url               34686 non-null  object
#  3   color                 34686 non-null  object
#  4   complectation_dict    6418 non-null   object
#  5   description           34686 non-null  object
#  6   engineDisplacement    34686 non-null  float64
#  7   enginePower           34686 non-null  int64
#  8   equipment_dict        24690 non-null  object
#  9   fuelType              34686 non-null  object
#  10  image                 34686 non-null  object
#  11  mileage               34686 non-null  int64
#  12  modelDate             34686 non-null  int64
#  13  model_info            34686 non-null  object
#  14  model_name            34686 non-null  object
#  15  name                  34686 non-null  object
#  16  numberOfDoors         34686 non-null  int64
#  17  parsing_unixtime      34686 non-null  int64
#  18  priceCurrency         34686 non-null  object
#  19  productionDate        34686 non-null  int64
#  20  sell_id               34686 non-null  int64
#  21  super_gen             34686 non-null  object
#  22  vehicleConfiguration  34686 non-null  object
#  23  vehicleTransmission   34686 non-null  object
#  24  vendor                34686 non-null  object
#  25  Владельцы             34686 non-null  int64
#  26  Владение              11995 non-null  object
#  27  ПТС                   34686 non-null  object
#  28  Привод                34686 non-null  object
#  29  Руль                  34686 non-null  object
#  30  Состояние             34686 non-null  object
#  31  Таможня               34686 non-null  object
#  32  engineDisplacement2   0 non-null      object
#  33  modelAge              34686 non-null  int64
#  34  autoAge               34686 non-null  int64
#  35  tax                   34686 non-null  int64
# dtypes: float64(1), int64(11), object(24)
# memory usage: 9.5+ MB

# %%
test[num_features].hist(figsize=(16, 10), bins=50)
# Out:
# array([[<AxesSubplot:title={'center':'mileage'}>,
#         <AxesSubplot:title={'center':'numberOfDoors'}>,
#         <AxesSubplot:title={'center':'enginePower'}>],
#        [<AxesSubplot:title={'center':'tax'}>,
#         <AxesSubplot:title={'center':'modelAge'}>,
#         <AxesSubplot:title={'center':'autoAge'}>],
#        [<AxesSubplot:title={'center':'engineDisplacement'}>,
#         <AxesSubplot:title={'center':'Владельцы'}>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# как видно, почти у всех показателей наблюдается смещение вправо. для того, чтобы распределение было более равномерным, попробуем прологарифировать эти данные

# %%
test_log = test.copy()
num_features_log = ['mileage', 'numberOfDoors', 'enginePower', 'tax', 'modelAge', 'autoAge', 'engineDisplacement', 'Владельцы']
for q in num_features_log:
    test_log[q] = test_log[q].apply(lambda w: np.log(w + 1))
    
test_log[num_features_log].hist(figsize=(16, 10), bins=50)
# Out:
# array([[<AxesSubplot:title={'center':'mileage'}>,
#         <AxesSubplot:title={'center':'numberOfDoors'}>,
#         <AxesSubplot:title={'center':'enginePower'}>],
#        [<AxesSubplot:title={'center':'tax'}>,
#         <AxesSubplot:title={'center':'modelAge'}>,
#         <AxesSubplot:title={'center':'autoAge'}>],
#        [<AxesSubplot:title={'center':'engineDisplacement'}>,
#         <AxesSubplot:title={'center':'Владельцы'}>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# логарифмирование "помогло" показателю возраста модели и возраста авто, а также мощности автомобилей и налога, их распределение
# стало более равномерным, соответственно, можем прологарифмировать эти колонки в общем датасете

# %%
test['mileage_log'] = np.log(test['mileage'] + 1)

# %%
test['engineDisplacement_log'] = np.log(test['engineDisplacement'] + 1)

# %%
test['enginePower_log'] = np.log(test['enginePower'] + 1)

# %%
test['tax_log'] = np.log(test['tax'] + 1)

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34686 entries, 0 to 34685
# Data columns (total 40 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   bodyType                34686 non-null  object
#  1   brand                   34686 non-null  object
#  2   car_url                 34686 non-null  object
#  3   color                   34686 non-null  object
#  4   complectation_dict      6418 non-null   object
#  5   description             34686 non-null  object
#  6   engineDisplacement      34686 non-null  float64
#  7   enginePower             34686 non-null  int64
#  8   equipment_dict          24690 non-null  object
#  9   fuelType                34686 non-null  object
#  10  image                   34686 non-null  object
#  11  mileage                 34686 non-null  int64
#  12  modelDate               34686 non-null  int64
#  13  model_info              34686 non-null  object
#  14  model_name              34686 non-null  object
#  15  name                    34686 non-null  object
#  16  numberOfDoors           34686 non-null  int64
#  17  parsing_unixtime        34686 non-null  int64
#  18  priceCurrency           34686 non-null  object
#  19  productionDate          34686 non-null  int64
#  20  sell_id                 34686 non-null  int64
#  21  super_gen               34686 non-null  object
#  22  vehicleConfiguration    34686 non-null  object
#  23  vehicleTransmission     34686 non-null  object
#  24  vendor                  34686 non-null  object
#  25  Владельцы               34686 non-null  int64
#  26  Владение                11995 non-null  object
#  27  ПТС                     34686 non-null  object
#  28  Привод                  34686 non-null  object
#  29  Руль                    34686 non-null  object
#  30  Состояние               34686 non-null  object
#  31  Таможня                 34686 non-null  object
#  32  engineDisplacement2     0 non-null      object
#  33  modelAge                34686 non-null  int64
#  34  autoAge                 34686 non-null  int64
#  35  tax                     34686 non-null  int64
#  36  mileage_log             34686 non-null  float64
#  37  engineDisplacement_log  34686 non-null  float64
#  38  enginePower_log         34686 non-null  float64
#  39  tax_log                 34686 non-null  float64
# dtypes: float64(5), int64(11), object(24)
# memory usage: 10.6+ MB

# %%
# Посмотрим корреляцию числовых признаков
sns.heatmap(test[num_features].corr().abs(), vmin=0, vmax=1, square=True,
              annot=True, fmt=".3f", linewidths=0.1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# как видно из тепловой карты, наибольшая корреляционная зависимость наблюдается между возрастом модели, годом выпуска авто. А также между мощностью машины и его объемом двигателя, и налогом, как производным признаком от мощности

# %% [markdown]
# # Feature Engineering

# %%
# преобразуем признаки enginePower и engineDisplacement

pf = PolynomialFeatures(2)
poly_features = pf.fit_transform(test[[ 'engineDisplacement', 'enginePower']])
poly = pd.DataFrame(poly_features).drop([0], axis = 1)
poly.columns = ['displacement_power_1', 'displacement_power_2', 'displacement_power_3', 'displacement_power_4',
              'displacement_power_5']

poly
# num_features = num_features + list(poly.columns)
# test = pd.concat([test, poly], axis=1)
# test.sample(3)
# Out:
#        displacement_power_1  displacement_power_2  displacement_power_3  \
# 0                       1.2                 105.0                  1.44
# 1                       1.6                 110.0                  2.56
# 2                       1.8                 152.0                  3.24
# 3                       1.6                 110.0                  2.56
# 4                       1.8                 152.0                  3.24
# ...                     ...                   ...                   ...
# 34681                   1.6                 136.0                  2.56
# 34682                   2.0                 190.0                  4.00
# 34683                   2.5                 170.0                  6.25
# 34684                   2.0                 184.0                  4.00
# 34685                   3.0                 235.0                  9.00
#
#        displacement_power_4  displacement_power_5
# 0                     126.0               11025.0
# 1                     176.0               12100.0
# 2                     273.6               23104.0
# 3                     176.0               12100.0
# 4                     273.6               23104.0
# ...                     ...                   ...
# 34681                 217.6               18496.0
# 34682                 380.0               36100.0
# 34683                 425.0               28900.0
# 34684                 368.0               33856.0
# 34685                 705.0               55225.0
#
# [34686 rows x 5 columns]

# %%
#Аналогично проделаем с другими признаками
pf = PolynomialFeatures(2)
poly_features = pf.fit_transform(test[['autoAge', 'modelAge']])
poly = pd.DataFrame(poly_features.mean(axis=1))
poly.columns = ['auto_model']
test = pd.concat([test, poly], axis=1)
test.sample(3)
# Out:
#                 bodyType     brand  \
# 14928  внедорожник 5 дв.  INFINITI
# 3650               седан      AUDI
# 12920  внедорожник 5 дв.    NISSAN
#
#                                                  car_url        color  \
# 14928  https://auto.ru/cars/used/sale/infiniti/jx/110...       чёрный
# 3650   https://auto.ru/cars/used/sale/audi/80/1100954...  серебристый
# 12920  https://auto.ru/cars/used/sale/nissan/x_trail/...        серый
#
#       complectation_dict                                        description  \
# 14928                NaN  Машиной пользуюсь каждый день.\nЧто было сдела...
# 3650                 NaN                       Машина на ходу сел и поехал
# 12920                NaN  Автомобиль в очень хорошем состоянии. Покупалс...
#
#        engineDisplacement  enginePower  \
# 14928                 3.5          265
# 3650                  1.8           90
# 12920                 2.0          141
#
#                                           equipment_dict fuelType  ...  \
# 14928                                                NaN   бензин  ...
# 3650                                                 NaN   бензин  ...
# 12920  {"engine-proof":true,"cruise-control":true,"as...   бензин  ...
#
#       mileage_log  engineDisplacement_log  enginePower_log    tax_log  \
# 14928   11.842236                1.504077         5.583496  10.590390
# 3650    12.611541                1.029619         4.510860   7.719130
# 12920   12.196027                1.098612         4.955827   8.504311
#
#       displacement_power_1 displacement_power_2  displacement_power_3  \
# 14928                  3.5                265.0                 12.25
# 3650                   1.8                 90.0                  3.24
# 12920                  2.0                141.0                  4.00
#
#        displacement_power_4 displacement_power_5  auto_model
# 14928                 927.5              70225.0   43.666667
# 3650                  162.0               8100.0  572.833333
# 12920                 282.0              19881.0   82.833333
#
# [3 rows x 46 columns]

# %% [markdown]
# некоторые категориальные признаки имеют 2 категории значений, некторые больше. Для признаков, имеющих 2 категории используем функцию LabelEncoder(), для других - OneHotEncoder()/get_dummies()

# %%
# с помощью LabelEncoder преобразуем все бинарные переменные в числовые
bin_cols = ['vendor', 'ПТС', 'Руль']
label_encoder = LabelEncoder()
for column in bin_cols:
    test[column] = label_encoder.fit_transform(test[column])

# убедимся в преобразовании    
test[['vendor', 'ПТС', 'Руль']].sample(5)
# Out:
#        vendor  ПТС  Руль
# 28980       1    0     0
# 14617       1    0     0
# 8758        0    1     0
# 9167        0    1     0
# 7985        0    1     0

# %%
# добавим сразу эти признаки в список числовых
num_features = num_features + bin_cols

# %%
# с помощью get_dummies преобразуем в dummy-переменные сохраним в одтельный датафрейм, который затем присоединим к основному
feature = ['bodyType', 'brand', 'color', 'fuelType','vehicleTransmission','Привод']

test2 = pd.get_dummies(test, columns=feature, drop_first=True)
test2.sample(5)
# Out:
#                                                  car_url complectation_dict  \
# 30968  https://auto.ru/cars/used/sale/volkswagen/pass...                NaN
# 15090  https://auto.ru/cars/used/sale/infiniti/fx/108...                NaN
# 8823   https://auto.ru/cars/used/sale/bmw/x6/10512947...                NaN
# 23295  https://auto.ru/cars/used/sale/volkswagen/jett...                NaN
# 17905  https://auto.ru/cars/used/sale/mercedes/gl_kla...                NaN
#
#                                              description  engineDisplacement  \
# 30968  Я владелец! в ПТС тоже я! машина в хорошем сос...                 2.0
# 15090  Авто в отличном состоянии и в оригинальном обв...                 5.0
# 8823   Своевременное обслуживание. Пройдено ТО на 130...                 3.0
# 23295  Только СЕГОДНЯ И ЗАВТРА при покупке этого авто...                 1.6
# 17905                     Комплект зимних шин в подарок.                 3.0
#
#        enginePower                                     equipment_dict  \
# 30968          140  {"engine-proof":true,"cruise-control":true,"as...
# 15090          420  {"asr":true,"tinted-glass":true,"esp":true,"ad...
# 8823           306  {"cruise-control":true,"asr":true,"tinted-glas...
# 23295           85  {"cruise-control":true,"alloy-wheel-disks":tru...
# 17905          249                                                NaN
#
#                                                    image  mileage  modelDate  \
# 30968  https://autoru.naydex.net/cSRr96A18/708ec0RhY5...   255000       2005
# 15090  https://autoru.naydex.net/LxPU17803/f5b8d77S/u...    48000       2011
# 8823   https://autoru.naydex.net/lICN99c69/9bc7d3Rr7k...   134000       2007
# 23295  https://avatars.mds.yandex.net/get-autoru-vos/...   160000       2014
# 17905  https://avatars.mds.yandex.net/get-autoru-vos/...   170000       2012
#
#                                               model_info  ... color_чёрный  \
# 30968  {"code":"PASSAT","name":"Passat","ru_name":"Па...  ...            1
# 15090  {"code":"FX","name":"FX","ru_name":"FX","morph...  ...            0
# 8823   {"code":"X6","name":"X6","ru_name":"Х6","morph...  ...            0
# 23295  {"code":"JETTA","name":"Jetta","ru_name":"Джет...  ...            0
# 17905  {"code":"GL_KLASSE","name":"GL-Класс","ru_name...  ...            1
#
#       fuelType_газ  fuelType_гибрид  fuelType_дизель fuelType_электро  \
# 30968            0                0                1                0
# 15090            0                0                0                0
# 8823             0                0                0                0
# 23295            0                0                0                0
# 17905            0                0                1                0
#
#        vehicleTransmission_вариатор  vehicleTransmission_механическая  \
# 30968                             0                                 1
# 15090                             0                                 0
# 8823                              0                                 0
# 23295                             0                                 1
# 17905                             0                                 0
#
#       vehicleTransmission_роботизированная Привод_передний  Привод_полный
# 30968                                    0               0              1
# 15090                                    0               0              1
# 8823                                     0               0              1
# 23295                                    0               1              0
# 17905                                    0               0              1
#
# [5 rows x 98 columns]

# %%
test2.duplicated(subset='sell_id', keep='first').value_counts()
# Out:
# False    34686
# dtype: int64

# %%
test2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34686 entries, 0 to 34685
# Data columns (total 98 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   car_url                               34686 non-null  object
#  1   complectation_dict                    6418 non-null   object
#  2   description                           34686 non-null  object
#  3   engineDisplacement                    34686 non-null  float64
#  4   enginePower                           34686 non-null  int64
#  5   equipment_dict                        24690 non-null  object
#  6   image                                 34686 non-null  object
#  7   mileage                               34686 non-null  int64
#  8   modelDate                             34686 non-null  int64
#  9   model_info                            34686 non-null  object
#  10  model_name                            34686 non-null  object
#  11  name                                  34686 non-null  object
#  12  numberOfDoors                         34686 non-null  int64
#  13  parsing_unixtime                      34686 non-null  int64
#  14  priceCurrency                         34686 non-null  object
#  15  productionDate                        34686 non-null  int64
#  16  sell_id                               34686 non-null  int64
#  17  super_gen                             34686 non-null  object
#  18  vehicleConfiguration                  34686 non-null  object
#  19  vendor                                34686 non-null  int64
#  20  Владельцы                             34686 non-null  int64
#  21  Владение                              11995 non-null  object
#  22  ПТС                                   34686 non-null  int64
#  23  Руль                                  34686 non-null  int64
#  24  Состояние                             34686 non-null  object
#  25  Таможня                               34686 non-null  object
#  26  engineDisplacement2                   0 non-null      object
#  27  modelAge                              34686 non-null  int64
#  28  autoAge                               34686 non-null  int64
#  29  tax                                   34686 non-null  int64
#  30  mileage_log                           34686 non-null  float64
#  31  engineDisplacement_log                34686 non-null  float64
#  32  enginePower_log                       34686 non-null  float64
#  33  tax_log                               34686 non-null  float64
#  34  displacement_power_1                  34686 non-null  float64
#  35  displacement_power_2                  34686 non-null  float64
#  36  displacement_power_3                  34686 non-null  float64
#  37  displacement_power_4                  34686 non-null  float64
#  38  displacement_power_5                  34686 non-null  float64
#  39  auto_model                            34686 non-null  float64
#  40  bodyType_внедорожник 5 дв.            34686 non-null  uint8
#  41  bodyType_внедорожник открытый         34686 non-null  uint8
#  42  bodyType_кабриолет                    34686 non-null  uint8
#  43  bodyType_компактвэн                   34686 non-null  uint8
#  44  bodyType_купе                         34686 non-null  uint8
#  45  bodyType_купе-хардтоп                 34686 non-null  uint8
#  46  bodyType_лимузин                      34686 non-null  uint8
#  47  bodyType_лифтбек                      34686 non-null  uint8
#  48  bodyType_микровэн                     34686 non-null  uint8
#  49  bodyType_минивэн                      34686 non-null  uint8
#  50  bodyType_пикап двойная кабина         34686 non-null  uint8
#  51  bodyType_пикап одинарная кабина       34686 non-null  uint8
#  52  bodyType_пикап полуторная кабина      34686 non-null  uint8
#  53  bodyType_родстер                      34686 non-null  uint8
#  54  bodyType_седан                        34686 non-null  uint8
#  55  bodyType_седан 2 дв.                  34686 non-null  uint8
#  56  bodyType_седан-хардтоп                34686 non-null  uint8
#  57  bodyType_тарга                        34686 non-null  uint8
#  58  bodyType_универсал 5 дв.              34686 non-null  uint8
#  59  bodyType_фастбек                      34686 non-null  uint8
#  60  bodyType_фургон                       34686 non-null  uint8
#  61  bodyType_хэтчбек 3 дв.                34686 non-null  uint8
#  62  bodyType_хэтчбек 5 дв.                34686 non-null  uint8
#  63  brand_BMW                             34686 non-null  uint8
#  64  brand_HONDA                           34686 non-null  uint8
#  65  brand_INFINITI                        34686 non-null  uint8
#  66  brand_LEXUS                           34686 non-null  uint8
#  67  brand_MERCEDES                        34686 non-null  uint8
#  68  brand_MITSUBISHI                      34686 non-null  uint8
#  69  brand_NISSAN                          34686 non-null  uint8
#  70  brand_SKODA                           34686 non-null  uint8
#  71  brand_TOYOTA                          34686 non-null  uint8
#  72  brand_VOLKSWAGEN                      34686 non-null  uint8
#  73  brand_VOLVO                           34686 non-null  uint8
#  74  color_белый                           34686 non-null  uint8
#  75  color_голубой                         34686 non-null  uint8
#  76  color_жёлтый                          34686 non-null  uint8
#  77  color_зелёный                         34686 non-null  uint8
#  78  color_золотистый                      34686 non-null  uint8
#  79  color_коричневый                      34686 non-null  uint8
#  80  color_красный                         34686 non-null  uint8
#  81  color_оранжевый                       34686 non-null  uint8
#  82  color_пурпурный                       34686 non-null  uint8
#  83  color_розовый                         34686 non-null  uint8
#  84  color_серебристый                     34686 non-null  uint8
#  85  color_серый                           34686 non-null  uint8
#  86  color_синий                           34686 non-null  uint8
#  87  color_фиолетовый                      34686 non-null  uint8
#  88  color_чёрный                          34686 non-null  uint8
#  89  fuelType_газ                          34686 non-null  uint8
#  90  fuelType_гибрид                       34686 non-null  uint8
#  91  fuelType_дизель                       34686 non-null  uint8
#  92  fuelType_электро                      34686 non-null  uint8
#  93  vehicleTransmission_вариатор          34686 non-null  uint8
#  94  vehicleTransmission_механическая      34686 non-null  uint8
#  95  vehicleTransmission_роботизированная  34686 non-null  uint8
#  96  Привод_передний                       34686 non-null  uint8
#  97  Привод_полный                         34686 non-null  uint8
# dtypes: float64(11), int64(14), object(15), uint8(58)
# memory usage: 12.5+ MB

# %%
# удалим лишние столбцы из доплонительного датафрейма
test2 = test2.drop(test2.columns[1], axis = 1)
test2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34686 entries, 0 to 34685
# Data columns (total 57 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   sell_id                               34686 non-null  int64
#  1   bodyType_кабриолет                    34686 non-null  uint8
#  2   bodyType_компактвэн                   34686 non-null  uint8
#  3   bodyType_купе                         34686 non-null  uint8
#  4   bodyType_купе-хардтоп                 34686 non-null  uint8
#  5   bodyType_лимузин                      34686 non-null  uint8
#  6   bodyType_лифтбек                      34686 non-null  uint8
#  7   bodyType_микровэн                     34686 non-null  uint8
#  8   bodyType_минивэн                      34686 non-null  uint8
#  9   bodyType_пикап двойная кабина         34686 non-null  uint8
#  10  bodyType_пикап одинарная кабина       34686 non-null  uint8
#  11  bodyType_пикап полуторная кабина      34686 non-null  uint8
#  12  bodyType_родстер                      34686 non-null  uint8
#  13  bodyType_седан                        34686 non-null  uint8
#  14  bodyType_седан 2 дв.                  34686 non-null  uint8
#  15  bodyType_седан-хардтоп                34686 non-null  uint8
#  16  bodyType_тарга                        34686 non-null  uint8
#  17  bodyType_универсал 5 дв.              34686 non-null  uint8
#  18  bodyType_фастбек                      34686 non-null  uint8
#  19  bodyType_фургон                       34686 non-null  uint8
#  20  bodyType_хэтчбек 3 дв.                34686 non-null  uint8
#  21  bodyType_хэтчбек 5 дв.                34686 non-null  uint8
#  22  brand_BMW                             34686 non-null  uint8
#  23  brand_HONDA                           34686 non-null  uint8
#  24  brand_INFINITI                        34686 non-null  uint8
#  25  brand_LEXUS                           34686 non-null  uint8
#  26  brand_MERCEDES                        34686 non-null  uint8
#  27  brand_MITSUBISHI                      34686 non-null  uint8
#  28  brand_NISSAN                          34686 non-null  uint8
#  29  brand_SKODA                           34686 non-null  uint8
#  30  brand_TOYOTA                          34686 non-null  uint8
#  31  brand_VOLKSWAGEN                      34686 non-null  uint8
#  32  brand_VOLVO                           34686 non-null  uint8
#  33  color_белый                           34686 non-null  uint8
#  34  color_голубой                         34686 non-null  uint8
#  35  color_жёлтый                          34686 non-null  uint8
#  36  color_зелёный                         34686 non-null  uint8
#  37  color_золотистый                      34686 non-null  uint8
#  38  color_коричневый                      34686 non-null  uint8
#  39  color_красный                         34686 non-null  uint8
#  40  color_оранжевый                       34686 non-null  uint8
#  41  color_пурпурный                       34686 non-null  uint8
#  42  color_розовый                         34686 non-null  uint8
#  43  color_серебристый                     34686 non-null  uint8
#  44  color_серый                           34686 non-null  uint8
#  45  color_синий                           34686 non-null  uint8
#  46  color_фиолетовый                      34686 non-null  uint8
#  47  color_чёрный                          34686 non-null  uint8
#  48  fuelType_газ                          34686 non-null  uint8
#  49  fuelType_гибрид                       34686 non-null  uint8
#  50  fuelType_дизель                       34686 non-null  uint8
#  51  fuelType_электро                      34686 non-null  uint8
#  52  vehicleTransmission_вариатор          34686 non-null  uint8
#  53  vehicleTransmission_механическая      34686 non-null  uint8
#  54  vehicleTransmission_роботизированная  34686 non-null  uint8
#  55  Привод_передний                       34686 non-null  uint8
#  56  Привод_полный                         34686 non-null  uint8
# dtypes: int64(1), uint8(56)
# memory usage: 2.1 MB

# %%
test = test.merge(test2, how='left', on = 'sell_id' ) #объединяем "разложенный" по признакам датафрейм с основным
test = test.drop(['bodyType', 'brand', 'color', 'fuelType','vehicleTransmission','Привод'], axis=1)
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34686 entries, 0 to 34685
# Columns: 382 entries, car_url to Привод_полный_y
# dtypes: float64(11), int64(15), object(15), uint8(341)
# memory usage: 22.4+ MB

# %%
imp_cat = Series(mutual_info_classif(test[num_features], test['price'], discrete_features =True), index = num_features)
imp_cat.sort_values(inplace = True)
imp_cat.plot(kind = 'barh')

# print(num_features)
# print(cat_features)
# Out:
# <AxesSubplot:>
